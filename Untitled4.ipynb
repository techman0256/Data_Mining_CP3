# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/predicted_scores.csv')
df
# Out:
#              Player   M1   M2   M3   M4   M5   M6   M7   M8  M9  M10  M11  \
# 0           V Kohli   85   55   16  103   95    0   88  101  51  101   51
# 1        R Ravindra  123   51    9   32   75  116    9  108  42  108   42
# 2         Q de Kock  100   20    4  109  174   24  114    5  41   38   22
# 3         RG Sharma    0  131   86   48   46   87    4   40  61   40   61
# 4        GJ Maxwell   15   31    0    3  106   41    0  201   0  156   40
# 5         DA Warner   41   11  163   13  104   81   15   18  53   18   53
# 6  HE vander Dussen  108    4   60   26    1   21  133   13  76   13   76
# 7       DJ Mitchell    0   48   89    1  130   54   24   29  43   29   43
# 8        AK Markram  106    1   42   56   60   91    6    9  25    9   25
#
#    Total
# 0    746
# 1    715
# 2    651
# 3    604
# 4    593
# 5    570
# 6    531
# 7    490
# 8    430

# %%
cent = []
for player in range(len(df)):
  century = 0
  for index, row in df.iteritems():
    if 'M' in index:
      if row[player] > 99:
        century += 1
  cent.append(century)
print(cent)
# Out:
# [3, 4, 4, 1, 3, 2, 2, 1, 1]
# <ipython-input-29-c3a501dbd1f1>:4: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for index, row in df.iteritems():

# %%
# add the new column for Centuries and then sort
df['Centuries'] = cent
df.sort_values(by=['Centuries'], inplace=True, ascending=False)
df
# Out:
#              Player   M1   M2   M3   M4   M5   M6   M7   M8  M9  M10  M11  \
# 1        R Ravindra  123   51    9   32   75  116    9  108  42  108   42
# 2         Q de Kock  100   20    4  109  174   24  114    5  41   38   22
# 0           V Kohli   85   55   16  103   95    0   88  101  51  101   51
# 4        GJ Maxwell   15   31    0    3  106   41    0  201   0  156   40
# 5         DA Warner   41   11  163   13  104   81   15   18  53   18   53
# 6  HE vander Dussen  108    4   60   26    1   21  133   13  76   13   76
# 3         RG Sharma    0  131   86   48   46   87    4   40  61   40   61
# 7       DJ Mitchell    0   48   89    1  130   54   24   29  43   29   43
# 8        AK Markram  106    1   42   56   60   91    6    9  25    9   25
#
#    Total  Centuries
# 1    715          4
# 2    651          4
# 0    746          3
# 4    593          3
# 5    570          2
# 6    531          2
# 3    604          1
# 7    490          1
# 8    430          1

# %%
rank = df["Player"].tolist()

# %%
print("Player with The most centuries in 2023 will be: ", rank[0], " and ", rank[1])
# Out:
# Player with The most centuries in 2023 will be:  R Ravindra  and  Q de Kock
